# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import os
# %matplotlib inline

import pandas as pd
pd.set_option('display.max_columns', 500)

import numpy as np
np.bool = np.bool_

from matplotlib import pyplot as plt
import seaborn as sns


pd.set_option("display.precision", 2)
from IPython.display import Image

import xgboost as xgb
import tensorflow as tf

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import SelectFromModel, VarianceThreshold

# %%
# training data without labels
features = pd.read_csv('dengue_features_train.csv')
label = pd.read_csv('dengue_labels_train.csv')
test = pd.read_csv('dengue_features_test.csv')

#training data with labels
df=pd.merge(features, label, how='left', on =['city', 'year', 'weekofyear'])

# %%
# split data by city
sj_features = features[features.city=='sj']
iq_features = features[features.city=='iq']
sj_labels = label[label.city=='sj']
iq_labels = label[label.city=='iq']

#load final test data
sj_test = test[test.city=='sj']
iq_test = test[test.city=='iq']

# %% [markdown]
# ### Features and their descriptions

# %%
# Step 1: fillna with most recent value , should use for different cities (2 seperate tables)
def fill_na(df):
    for feature in df.keys():
        df[feature].fillna(method='ffill', inplace=True)
    return df

# Step 2 : fix wrong values
def wrong_week_num(df):
    df.loc[df["weekofyear"] == 53, "weekofyear"] = 1
    return df

# Step 3 : month & season featurea
def season_feature(df):
    df['season']=0
    df['month'] = pd.DatetimeIndex(df['week_start_date']).month.astype(int)
    df.loc[(df['month'] >= 3) & (df['month'] <6), 'season'] = 1
    df.loc[(df['month'] >= 6) & (df['month'] <9), 'season'] = 2
    df.loc[(df['month'] >= 9) & (df['month'] <12), 'season'] = 3
    df.loc[(df['month'] == 12) & (df['month'] <=2), 'season'] = 4
    return df

# cyclincal time feature
def other_time_features(df):
    day = 60*60*24
    week = 7*day
    year = 365.2425*day
    df['week_start_date'] = pd.to_datetime(df['week_start_date'])#, format='%Y.%m.%d %H:%M:%S') # convert datetype
    df['Seconds'] = df['week_start_date'].map(pd.Timestamp.timestamp) # convert to Seconds
    df['week_sin'] = np.sin(df['Seconds'] * (2* np.pi / week))
    df['week_cos'] = np.cos(df['Seconds'] * (2 * np.pi / week))
    df['year_sin'] = np.sin(df['Seconds'] * (2 * np.pi / year))
    df['year_cos'] = np.cos(df['Seconds'] * (2 * np.pi / year))
    df=df.drop(['Seconds', 'week_start_date'], axis=1)
    return df

def avg_feature(df):
    df['avg_reanalysis'] = df[['reanalysis_air_temp_k','reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
                                    'reanalysis_max_air_temp_k','reanalysis_min_air_temp_k']].mean(axis = 1)
    df['avg_ndvi'] = df[['ndvi_se','ndvi_sw','ndvi_ne','ndvi_nw']].mean(axis = 1)
    df = df.drop('city', axis=1)
    return df

# %%
def data_cleaning(df):
    df_new = df.copy()
    df_new = fill_na(df_new)
    df_new = wrong_week_num(df_new)
    df_new = season_feature(df_new)
    df_new = other_time_features(df_new)
    df_new = avg_feature(df_new)
    return df_new

# %%
sj_feat = data_cleaning(sj_features)
iq_feat = data_cleaning(iq_features)

sj_test1 = data_cleaning(sj_test)
iq_test1 = data_cleaning(iq_test)

# %%
sj_feat.head(2)
sj_test1.head(2)
# Out:
#    year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 0  1990          18     0.12     0.10     0.20     0.18                 12.42
# 1  1990          19     0.17     0.14     0.16     0.16                 22.82
#
#    reanalysis_air_temp_k  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0                 297.57                 297.74                       292.41
# 1                 298.21                 298.44                       293.95
#
#    reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# 0                      299.8                      295.9
# 1                      300.9                      296.4
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                                 73.37
# 1                            17.94                                 77.37
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                                  14.01
# 1                         22.82                                  15.37
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0               2.63               25.44                     6.90
# 1               2.37               26.71                     6.37
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  season  month  \
# 0                29.4                20.0               16.0       1      4
# 1                31.7                22.2                8.6       1      5
#
#    week_sin  week_cos  year_sin  year_cos  avg_reanalysis  avg_ndvi
# 0     -0.43      -0.9      0.89     -0.46          296.69      0.15
# 1     -0.43      -0.9      0.83     -0.56          297.58      0.16
#    year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 0  2008          18    -0.02    -0.02     0.10     0.09                 78.60
# 1  2008          19    -0.02    -0.01     0.08     0.07                 12.56
#
#    reanalysis_air_temp_k  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0                 298.49                 298.55                       294.53
# 1                 298.48                 298.56                       294.40
#
#    reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# 0                      301.1                      296.4
# 1                      300.8                      296.7
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            25.37                                 78.78
# 1                            21.83                                 78.23
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         78.60                                  15.92
# 1                         12.56                                  15.79
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0               3.13               26.53                     7.06
# 1               2.57               26.07                     5.56
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  season  month  \
# 0                33.3                21.7               75.2       1      4
# 1                30.0                22.2               34.3       1      5
#
#    week_sin  week_cos  year_sin  year_cos  avg_reanalysis  avg_ndvi
# 0     -0.97     -0.22      0.89     -0.46          297.81      0.04
# 1     -0.97     -0.22      0.83     -0.56          297.79      0.03

# %% [markdown]
# ### Dengue fever symptomsusually begin 4–10 days after infection and last for 2–7 days. We should add lag variables in model

# %%
# add lags
no_lag_features = ['season','month','week_sin','week_cos','year_sin',\
                   'year_cos', 'year', 'weekofyear','avg_reanalysis','avg_ndvi']

def lag(df):
    for column in df:
        df_sum = 0
        for i in range(2):
            not_lagged = no_lag_features
            if column not in not_lagged:
                new_var_name = column + "_lag_"+str(i+1)
                df[new_var_name] = df[column].shift(-(i+1))
                df_sum += df[column].shift(-(i+1))
    return df

# %%
sj_X1 = lag(sj_feat).fillna(method='ffill')
iq_X1 = lag(iq_feat).fillna(method='ffill')

sj_test2 = lag(sj_test1).fillna(method='ffill')
iq_test2 = lag(iq_test1).fillna(method='ffill')

sj_X1.head(2)
# Out:
#    year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 0  1990          18     0.12     0.10     0.20     0.18                 12.42
# 1  1990          19     0.17     0.14     0.16     0.16                 22.82
#
#    reanalysis_air_temp_k  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0                 297.57                 297.74                       292.41
# 1                 298.21                 298.44                       293.95
#
#    reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# 0                      299.8                      295.9
# 1                      300.9                      296.4
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                                 73.37
# 1                            17.94                                 77.37
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                                  14.01
# 1                         22.82                                  15.37
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0               2.63               25.44                     6.90
# 1               2.37               26.71                     6.37
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  season  month  \
# 0                29.4                20.0               16.0       1      4
# 1                31.7                22.2                8.6       1      5
#
#    week_sin  week_cos  year_sin  year_cos  avg_reanalysis  avg_ndvi  \
# 0     -0.43      -0.9      0.89     -0.46          296.69      0.15
# 1     -0.43      -0.9      0.83     -0.56          297.58      0.16
#
#    ndvi_ne_lag_1  ndvi_ne_lag_2  ndvi_nw_lag_1  ndvi_nw_lag_2  ndvi_se_lag_1  \
# 0           0.17           0.03           0.14           0.17           0.16
# 1           0.03           0.13           0.17           0.25           0.16
#
#    ndvi_se_lag_2  ndvi_sw_lag_1  ndvi_sw_lag_2  precipitation_amt_mm_lag_1  \
# 0           0.16           0.16           0.17                       22.82
# 1           0.23           0.17           0.24                       34.54
#
#    precipitation_amt_mm_lag_2  reanalysis_air_temp_k_lag_1  \
# 0                       34.54                       298.21
# 1                       15.36                       298.78
#
#    reanalysis_air_temp_k_lag_2  reanalysis_avg_temp_k_lag_1  \
# 0                       298.78                       298.44
# 1                       298.99                       298.88
#
#    reanalysis_avg_temp_k_lag_2  reanalysis_dew_point_temp_k_lag_1  \
# 0                       298.88                             293.95
# 1                       299.23                             295.43
#
#    reanalysis_dew_point_temp_k_lag_2  reanalysis_max_air_temp_k_lag_1  \
# 0                             295.43                            300.9
# 1                             295.31                            300.5
#
#    reanalysis_max_air_temp_k_lag_2  reanalysis_min_air_temp_k_lag_1  \
# 0                            300.5                            296.4
# 1                            301.4                            297.3
#
#    reanalysis_min_air_temp_k_lag_2  reanalysis_precip_amt_kg_per_m2_lag_1  \
# 0                            297.3                                  17.94
# 1                            297.0                                  26.10
#
#    reanalysis_precip_amt_kg_per_m2_lag_2  \
# 0                                   26.1
# 1                                   13.9
#
#    reanalysis_relative_humidity_percent_lag_1  \
# 0                                       77.37
# 1                                       82.05
#
#    reanalysis_relative_humidity_percent_lag_2  \
# 0                                       82.05
# 1                                       80.34
#
#    reanalysis_sat_precip_amt_mm_lag_1  reanalysis_sat_precip_amt_mm_lag_2  \
# 0                               22.82                               34.54
# 1                               34.54                               15.36
#
#    reanalysis_specific_humidity_g_per_kg_lag_1  \
# 0                                        15.37
# 1                                        16.85
#
#    reanalysis_specific_humidity_g_per_kg_lag_2  reanalysis_tdtr_k_lag_1  \
# 0                                        16.85                     2.37
# 1                                        16.67                     2.30
#
#    reanalysis_tdtr_k_lag_2  station_avg_temp_c_lag_1  \
# 0                     2.30                     26.71
# 1                     2.43                     26.71
#
#    station_avg_temp_c_lag_2  station_diur_temp_rng_c_lag_1  \
# 0                     26.71                           6.37
# 1                     27.47                           6.49
#
#    station_diur_temp_rng_c_lag_2  station_max_temp_c_lag_1  \
# 0                           6.49                      31.7
# 1                           6.77                      32.2
#
#    station_max_temp_c_lag_2  station_min_temp_c_lag_1  \
# 0                      32.2                      22.2
# 1                      33.3                      22.8
#
#    station_min_temp_c_lag_2  station_precip_mm_lag_1  station_precip_mm_lag_2
# 0                      22.8                      8.6                     41.4
# 1                      23.3                     41.4                      4.0

# %% [markdown]
# ### Now we have 70 columns with lags

# %%
# lets create variables from total cases
cases_avg = pd.DataFrame(df.groupby(['city', 'weekofyear'])['total_cases'].mean())
cases_avg = cases_avg.rename(columns={"total_cases": "avg_weekly_cases"})
cases_avg = cases_avg.reset_index()
cases_avg.head()
# Out:
#   city  weekofyear  avg_weekly_cases
# 0   iq           1               9.3
# 1   iq           2              13.8
# 2   iq           3              10.8
# 3   iq           4              15.8
# 4   iq           5              14.8

# %%
sj_X2 = sj_X1.merge(cases_avg[cases_avg.city=='sj'], how ='left', on = ['weekofyear']).drop('city', axis=1)
iq_X2 = iq_X1.merge(cases_avg[cases_avg.city=='iq'], how ='left', on = ['weekofyear']).drop('city', axis=1)

sj_test3 = sj_test2.merge(cases_avg[cases_avg.city=='sj'], how ='left', on = ['weekofyear']).drop('city', axis=1)
iq_test3= iq_test2.merge(cases_avg[cases_avg.city=='iq'], how ='left', on = ['weekofyear']).drop('city', axis=1)

sj_X2.head(2)
sj_test3.head(2)
# Out:
#    year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 0  1990          18     0.12     0.10     0.20     0.18                 12.42
# 1  1990          19     0.17     0.14     0.16     0.16                 22.82
#
#    reanalysis_air_temp_k  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0                 297.57                 297.74                       292.41
# 1                 298.21                 298.44                       293.95
#
#    reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# 0                      299.8                      295.9
# 1                      300.9                      296.4
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                                 73.37
# 1                            17.94                                 77.37
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                                  14.01
# 1                         22.82                                  15.37
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0               2.63               25.44                     6.90
# 1               2.37               26.71                     6.37
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  season  month  \
# 0                29.4                20.0               16.0       1      4
# 1                31.7                22.2                8.6       1      5
#
#    week_sin  week_cos  year_sin  year_cos  avg_reanalysis  avg_ndvi  \
# 0     -0.43      -0.9      0.89     -0.46          296.69      0.15
# 1     -0.43      -0.9      0.83     -0.56          297.58      0.16
#
#    ndvi_ne_lag_1  ndvi_ne_lag_2  ndvi_nw_lag_1  ndvi_nw_lag_2  ndvi_se_lag_1  \
# 0           0.17           0.03           0.14           0.17           0.16
# 1           0.03           0.13           0.17           0.25           0.16
#
#    ndvi_se_lag_2  ndvi_sw_lag_1  ndvi_sw_lag_2  precipitation_amt_mm_lag_1  \
# 0           0.16           0.16           0.17                       22.82
# 1           0.23           0.17           0.24                       34.54
#
#    precipitation_amt_mm_lag_2  reanalysis_air_temp_k_lag_1  \
# 0                       34.54                       298.21
# 1                       15.36                       298.78
#
#    reanalysis_air_temp_k_lag_2  reanalysis_avg_temp_k_lag_1  \
# 0                       298.78                       298.44
# 1                       298.99                       298.88
#
#    reanalysis_avg_temp_k_lag_2  reanalysis_dew_point_temp_k_lag_1  \
# 0                       298.88                             293.95
# 1                       299.23                             295.43
#
#    reanalysis_dew_point_temp_k_lag_2  reanalysis_max_air_temp_k_lag_1  \
# 0                             295.43                            300.9
# 1                             295.31                            300.5
#
#    reanalysis_max_air_temp_k_lag_2  reanalysis_min_air_temp_k_lag_1  \
# 0                            300.5                            296.4
# 1                            301.4                            297.3
#
#    reanalysis_min_air_temp_k_lag_2  reanalysis_precip_amt_kg_per_m2_lag_1  \
# 0                            297.3                                  17.94
# 1                            297.0                                  26.10
#
#    reanalysis_precip_amt_kg_per_m2_lag_2  \
# 0                                   26.1
# 1                                   13.9
#
#    reanalysis_relative_humidity_percent_lag_1  \
# 0                                       77.37
# 1                                       82.05
#
#    reanalysis_relative_humidity_percent_lag_2  \
# 0                                       82.05
# 1                                       80.34
#
#    reanalysis_sat_precip_amt_mm_lag_1  reanalysis_sat_precip_amt_mm_lag_2  \
# 0                               22.82                               34.54
# 1                               34.54                               15.36
#
#    reanalysis_specific_humidity_g_per_kg_lag_1  \
# 0                                        15.37
# 1                                        16.85
#
#    reanalysis_specific_humidity_g_per_kg_lag_2  reanalysis_tdtr_k_lag_1  \
# 0                                        16.85                     2.37
# 1                                        16.67                     2.30
#
#    reanalysis_tdtr_k_lag_2  station_avg_temp_c_lag_1  \
# 0                     2.30                     26.71
# 1                     2.43                     26.71
#
#    station_avg_temp_c_lag_2  station_diur_temp_rng_c_lag_1  \
# 0                     26.71                           6.37
# 1                     27.47                           6.49
#
#    station_diur_temp_rng_c_lag_2  station_max_temp_c_lag_1  \
# 0                           6.49                      31.7
# 1                           6.77                      32.2
#
#    station_max_temp_c_lag_2  station_min_temp_c_lag_1  \
# 0                      32.2                      22.2
# 1                      33.3                      22.8
#
#    station_min_temp_c_lag_2  station_precip_mm_lag_1  station_precip_mm_lag_2  \
# 0                      22.8                      8.6                     41.4
# 1                      23.3                     41.4                      4.0
#
#    avg_weekly_cases
# 0             10.72
# 1              9.94
#    year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 0  2008          18    -0.02    -0.02     0.10     0.09                 78.60
# 1  2008          19    -0.02    -0.01     0.08     0.07                 12.56
#
#    reanalysis_air_temp_k  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0                 298.49                 298.55                       294.53
# 1                 298.48                 298.56                       294.40
#
#    reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# 0                      301.1                      296.4
# 1                      300.8                      296.7
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            25.37                                 78.78
# 1                            21.83                                 78.23
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         78.60                                  15.92
# 1                         12.56                                  15.79
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0               3.13               26.53                     7.06
# 1               2.57               26.07                     5.56
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  season  month  \
# 0                33.3                21.7               75.2       1      4
# 1                30.0                22.2               34.3       1      5
#
#    week_sin  week_cos  year_sin  year_cos  avg_reanalysis  avg_ndvi  \
# 0     -0.97     -0.22      0.89     -0.46          297.81      0.04
# 1     -0.97     -0.22      0.83     -0.56          297.79      0.03
#
#    ndvi_ne_lag_1  ndvi_ne_lag_2  ndvi_nw_lag_1  ndvi_nw_lag_2  ndvi_se_lag_1  \
# 0      -1.80e-02      -1.50e-03          -0.01          -0.01           0.08
# 1      -1.50e-03      -1.50e-03          -0.01          -0.02           0.15
#
#    ndvi_se_lag_2  ndvi_sw_lag_1  ndvi_sw_lag_2  precipitation_amt_mm_lag_1  \
# 0           0.15           0.07           0.09                       12.56
# 1           0.12           0.09           0.13                        3.66
#
#    precipitation_amt_mm_lag_2  reanalysis_air_temp_k_lag_1  \
# 0                        3.66                       298.48
# 1                        0.00                       299.46
#
#    reanalysis_air_temp_k_lag_2  reanalysis_avg_temp_k_lag_1  \
# 0                       299.46                       298.56
# 1                       299.69                       299.36
#
#    reanalysis_avg_temp_k_lag_2  reanalysis_dew_point_temp_k_lag_1  \
# 0                       299.36                             294.40
# 1                       299.73                             295.31
#
#    reanalysis_dew_point_temp_k_lag_2  reanalysis_max_air_temp_k_lag_1  \
# 0                             295.31                            300.8
# 1                             294.40                            302.2
#
#    reanalysis_max_air_temp_k_lag_2  reanalysis_min_air_temp_k_lag_1  \
# 0                            302.2                            296.7
# 1                            303.0                            296.4
#
#    reanalysis_min_air_temp_k_lag_2  reanalysis_precip_amt_kg_per_m2_lag_1  \
# 0                            296.4                                  21.83
# 1                            296.9                                   4.12
#
#    reanalysis_precip_amt_kg_per_m2_lag_2  \
# 0                                   4.12
# 1                                   2.20
#
#    reanalysis_relative_humidity_percent_lag_1  \
# 0                                       78.23
# 1                                       78.27
#
#    reanalysis_relative_humidity_percent_lag_2  \
# 0                                       78.27
# 1                                       73.02
#
#    reanalysis_sat_precip_amt_mm_lag_1  reanalysis_sat_precip_amt_mm_lag_2  \
# 0                               12.56                                3.66
# 1                                3.66                                0.00
#
#    reanalysis_specific_humidity_g_per_kg_lag_1  \
# 0                                        15.79
# 1                                        16.67
#
#    reanalysis_specific_humidity_g_per_kg_lag_2  reanalysis_tdtr_k_lag_1  \
# 0                                        16.67                     2.57
# 1                                        15.78                     4.43
#
#    reanalysis_tdtr_k_lag_2  station_avg_temp_c_lag_1  \
# 0                     4.43                     26.07
# 1                     4.34                     27.93
#
#    station_avg_temp_c_lag_2  station_diur_temp_rng_c_lag_1  \
# 0                     27.93                           5.56
# 1                     28.06                           7.79
#
#    station_diur_temp_rng_c_lag_2  station_max_temp_c_lag_1  \
# 0                           7.79                      30.0
# 1                           6.27                      32.8
#
#    station_max_temp_c_lag_2  station_min_temp_c_lag_1  \
# 0                      32.8                      22.2
# 1                      33.3                      22.8
#
#    station_min_temp_c_lag_2  station_precip_mm_lag_1  station_precip_mm_lag_2  \
# 0                      22.8                     34.3                      3.0
# 1                      24.4                      3.0                      0.3
#
#    avg_weekly_cases
# 0             10.72
# 1              9.94

# %%
# splitting data into train & val
# This step is for feature selection

sj_train, sj_val, sj_train_label, sj_val_label = train_test_split(sj_X2, sj_labels, test_size=0.2)
iq_train, iq_val, iq_train_label, iq_test_label = train_test_split(iq_X2, iq_labels, test_size=0.2)

# %%
from xgboost import plot_importance
sj_model = xgb.XGBRegressor()
sj_model.fit(sj_train._get_numeric_data(), sj_train_label._get_numeric_data())
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# feature importance
results=pd.DataFrame()
results['columns']=sj_train.columns
results['importances'] = sj_model.feature_importances_
results.sort_values(by='importances',ascending=False,inplace=True)

results[:20]
# Out:
#                                         columns  importances
# 4                                       ndvi_se     2.13e-01
# 57  reanalysis_specific_humidity_g_per_kg_lag_2     1.49e-01
# 56  reanalysis_specific_humidity_g_per_kg_lag_1     9.85e-02
# 26                                     year_sin     8.36e-02
# 23                                        month     7.53e-02
# 22                                       season     5.22e-02
# 43                  reanalysis_avg_temp_k_lag_2     4.35e-02
# 25                                     week_cos     3.30e-02
# 45            reanalysis_dew_point_temp_k_lag_2     3.16e-02
# 64                     station_max_temp_c_lag_1     2.38e-02
# 24                                     week_sin     1.78e-02
# 70                             avg_weekly_cases     1.70e-02
# 1                                    weekofyear     1.36e-02
# 27                                     year_cos     1.31e-02
# 35                                ndvi_se_lag_2     9.90e-03
# 10                    reanalysis_max_air_temp_k     9.02e-03
# 65                     station_max_temp_c_lag_2     7.91e-03
# 0                                          year     7.80e-03
# 58                      reanalysis_tdtr_k_lag_1     7.71e-03
# 41                  reanalysis_air_temp_k_lag_2     6.51e-03

# %%
plot_importance(sj_model, max_num_features=25)
plt.show()
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# Lets do feature selection:

col_selected = ['avg_weekly_cases', 'reanalysis_specific_humidity_g_per_kg_lag_2',
      'reanalysis_specific_humidity_g_per_kg','ndvi_se_lag_1',
      'reanalysis_dew_point_temp_k_lag_1','station_max_temp_c_lag_1',
      'reanalysis_specific_humidity_g_per_kg_lag_1' , 'station_min_temp_c_lag_2']

sj_X_new = sj_X2[col_selected]
iq_X_new = iq_X2[col_selected]


sj_test_new = sj_test3[col_selected]
iq_test_new = iq_test3[col_selected]

# %%
# XGB takes long time

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

sj_train, sj_val, sj_train_label, sj_val_label = train_test_split(sj_X_new, sj_labels, test_size=0.2)
iq_train, iq_val, iq_train_label, iq_test_label = train_test_split(iq_X_new, iq_labels, test_size=0.2)


# XGradient Boost
sj_xgb = xgb.XGBRegressor(n_estimators = 1000, #  boosted trees
                                learning_rate = 0.005,
                                max_depth = 8,
                                subsample = 0.75,
                                colsample_bytree = 0.75,
                                gamma = .025,
                                nthread = 4)

sj_model = sj_xgb.fit(sj_train, sj_train_label.total_cases)

"""grid_param = {
    'n_estimators': [100, 500,1000],
    'learning_rate': [ 0.005, 0.01, 0.1],
    'max_depth': [6, 9, 12],
    'subsample': [0.75, 1.0],
    'colsample_bytree': [0.75, 1.0],
    'gamma' : [0.025, 0.01],
    'nthread' : [4,8]
    }

sj_xgb_grid = GridSearchCV(estimator=xg_clf,
                     param_grid=grid_param,
                     scoring='neg_mean_squared_error',
                     cv=5)
sj_xgb_grid.fit(sj_train, sj_train_label.total_cases)

"""
# Out:
# "grid_param = {\n    'n_estimators': [100, 500,1000],\n    'learning_rate': [ 0.005, 0.01, 0.1],\n    'max_depth': [6, 9, 12],\n    'subsample': [0.75, 1.0],\n    'colsample_bytree': [0.75, 1.0], \n    'gamma' : [0.025, 0.01],\n    'nthread' : [4,8]\n    }\n\nsj_xgb_grid = GridSearchCV(estimator=xg_clf,\n                     param_grid=grid_param,\n                     scoring='neg_mean_squared_error',\n                     cv=5)\nsj_xgb_grid.fit(sj_train, sj_train_label.total_cases)\n\n"

# %%
#sj_xgb_grid.estimators_[0].best_params_  # for the first y_target estimator

sj_pred = sj_model.predict(sj_val)
score = metrics.mean_absolute_error(sj_val_label.total_cases,sj_pred)
print(score) #MAE
# Out:
# 18.50841213287191

# %%
sj_val_results = pd.DataFrame(data={'Val_Predictions':sj_pred, 'Actuals':sj_val_label.total_cases}).reset_index()
plt.plot(sj_val_results['Val_Predictions'], color='red',label="Predictions")
plt.plot(sj_val_results['Actuals'], color='green',label="Actuals")
plt.legend(loc='upper right')

# %%
# compare two predictions by figures
plt.subplot(211)
plt.plot(sj_val_results.Val_Predictions, color="red", label="Predictions")
plt.legend(loc='upper right')
plt.subplot(212)
plt.plot(sj_val_results.Actuals, color='green',label="Actual")

plt.suptitle("Dengue Predicted Cases vs. Actual Cases in San Juan")
plt.legend()
plt.show()
# Out:
# <Axes: >
# <Axes: >
# Text(0.5, 0.98, 'Dengue Predicted Cases vs. Actual Cases in San Juan')

# %%
# Train on full data
sj_model_fulldata = sj_xgb.fit(sj_X_new, sj_labels.total_cases)
sj_testset_prd = sj_model_fulldata.predict(sj_test_new)

# %%
# IQ model

iq_train, iq_val, iq_train_label, iq_val_label = train_test_split(iq_X_new, iq_labels, test_size=0.2)
iq_train, iq_val, iq_train_label, iq_test_label = train_test_split(iq_X_new, iq_labels, test_size=0.2)


# XGradient Boost
iq_xgb = xgb.XGBRegressor(n_estimators = 1000, #  boosted trees
                                learning_rate = 0.005,
                                max_depth = 8,
                                subsample = 0.75,
                                colsample_bytree = 0.75,
                                gamma = .025,
                                nthread = 4)

iq_model = sj_xgb.fit(iq_train, iq_train_label.total_cases)

# %%
iq_pred = iq_model.predict(iq_val)
score = metrics.mean_absolute_error(iq_val_label.total_cases,iq_pred)
print(score) #MAE
# Out:
# 8.375236099729172

# %%
iq_val_results = pd.DataFrame(data={'Val_Predictions':iq_pred, 'Actuals':iq_val_label.total_cases}).reset_index()
plt.plot(iq_val_results['Val_Predictions'], color='red',label="Predictions")
plt.plot(iq_val_results['Actuals'], color='green',label="Actuals")
plt.legend(loc='upper right')

# %%
# compare two predictions by figures
plt.subplot(211)
plt.plot(iq_val_results.Val_Predictions, color="red", label="Predictions")
plt.legend(loc='upper right')
plt.subplot(212)
plt.plot(iq_val_results.Actuals, color='green',label="Actual")

plt.suptitle("Dengue Predicted Cases vs. Actual Cases in San Juan")
plt.legend()
plt.show()
# Out:
# <Axes: >
# <Axes: >
# Text(0.5, 0.98, 'Dengue Predicted Cases vs. Actual Cases in San Juan')

# %%
# Train on full data
iq_model_fulldata = iq_xgb.fit(iq_X_new, iq_labels.total_cases)
iq_testset_prd = iq_model_fulldata.predict(iq_test_new)

# %%
pred=pd.read_csv('submission_format.csv')#, index=[0,1,2])
pred = pred.set_index(['city','year','weekofyear']).drop('total_cases', axis=1)
pred.head(2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(sj, 2008, 18), (sj, 2008, 19)]

# %%
pred['total_cases'] = pd.DataFrame(sj_testset_prd).append(pd.DataFrame(iq_testset_prd)).to_numpy()
pred= pred[['total_cases']].round(0).astype(int)
pred
# Out:
# <ipython-input-55-75ca3ebc9f00>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pred['total_cases'] = pd.DataFrame(sj_testset_prd).append(pd.DataFrame(iq_testset_prd)).to_numpy()
#                       total_cases
# city year weekofyear
# sj   2008 18                    4
#           19                   13
#           20                   15
#           21                   16
#           22                   12
# ...                           ...
# iq   2013 22                    5
#           23                    3
#           24                    3
#           25                    3
#           26                    3
#
# [416 rows x 1 columns]

# %%
pred.to_csv('xgb_results.csv')

# %%
# Good results, MAE: 24.1418
